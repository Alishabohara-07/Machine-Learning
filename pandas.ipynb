# %% [markdown]
# <a href="https://colab.research.google.com/github/Alishabohara-07/Machine-Learning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Pandas
#
#
# Data preprocessing in Machine learning using pandas.
#
# Data preprocessing is required tasks for cleasning  the data and making it suitable for a machine learning model which also increases the accuracy and efficiency of a machine learning model.
#
#
# Pandas is an open source Python  package that is most widelyused for data science/data analysis  and machine learning tasks. It is built on top of another package named Numpy, which provides  support for multi dimensional arrays. Preprocessing is the process of doing a pre-analysis  of data, in order to transform them into a standard and normalized format.
#
#
# Preprocessing involves following aspects:
#
#  -missing values
#
#  -data standardization
#
#  -data normalization
#
#  -data minning

# %%
import pandas as pd

# %%
data = {
    "cars": ["bmw", "honda", "suzuki", "BYD" ],
    "models": ["2007", "2009", "2008", "2023"],
    "passengers": ["5", "5", "6", "7"]
}
#print(data)
data
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'BYD'],
#  'models': ['2007', '2009', '2008', '2023'],
#  'passengers': ['5', '5', '6', '7']}

# %%
#convert the data into dataframe
df =  pd.DataFrame(data)
df
# Out:
#      cars models passengers
# 0     bmw   2007          5
# 1   honda   2009          5
# 2  suzuki   2008          6
# 3     BYD   2023          7

# %%
# save the file as  CSV file
df.to_csv("/content/drive/MyDrive/python/6thsem/car_data.csv")

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#Pandas Series
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a)
#myvar
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
#create labels  in pandas with index
a = [1, 7, 2]
myvar = pd.Series(a, index=["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["x"])
# Out:
# 1

# %%
#create a dataframe named df, with data calories and duration.

data = {
    "calories" : [400, 503, 606],
    "duration" :[30, 50, 80]


      }

# %%
#convert the data into dataframe
df =  pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       400        30
# 1       503        50
# 2       606        80

# %%
print(df.loc[1])
# Out:
# calories    503
# duration     50
# Name: 1, dtype: int64

# %%
print(df.loc[[1, 2]])
# Out:
#    calories  duration
# 1       503        50
# 2       606        80

# %%
import pandas as pd

data = {
    "calories" : [400, 503, 606],
    "duration" :[30, 50, 80]


      }
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)
# Out:
#       calories  duration
# day1       400        30
# day2       503        50
# day3       606        80
